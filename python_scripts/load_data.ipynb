# %%
from sqlalchemy import create_engine
import os

db_password = os.environ.get("DB_PASSWORD")
if db_password is None:
    raise RuntimeError("Please set DB_PASSWORD environment variable before running this notebook")

engine = create_engine(f"mysql+pymysql://root:{db_password}@localhost:3306/streamflix_db")

# %%
import os
os.chdir("/Users/alenasemenova/DataAnalystCourse/da07work/19_Project_Maverik")
print(os.getcwd())
# Out:
# /Users/alenasemenova/DataAnalystCourse/da07work/19_Project_Maverik

# %%
import pandas as pd
movies = pd.read_csv("movies_cleaned.csv")
movies = movies.rename(columns={'Total Views': 'TotalViews'})

# %%
import os
print(os.getcwd())
# Out:
# /Users/alenasemenova/DataAnalystCourse/da07work

# %%
import pandas as pd
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings_Dataset.csv")

# %%
movies.to_sql('Movies', con=engine, if_exists='append', index=False)
# Out:
# 3883

# %%
users.to_sql('Users', con=engine, if_exists='append', index=False)
# Out:
# 6040

# %%
ratings.to_sql('Ratings', con=engine, if_exists='append', index=False)
# Out:
# 10000
